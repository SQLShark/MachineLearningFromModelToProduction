# %% [markdown]
# In this notebook we are looking to explore the data which we will be working with. Let's start by importing the data.

# %%
from sklearn import datasets, linear_model
diabetes = datasets.load_diabetes()

import numpy as np

# %% [markdown]
# Next I am going to use Pandas to play with the data. I could do most of this in base Python, but Pandas is better suited for it.

# %%
import pandas as pd

# %% [markdown]
# I am going to create a new DataFrame with the diabetes data.

# %%
diabetespd = pd.DataFrame(diabetes.data)

# %% [markdown]
# Lets look at the head of our data to see what we are working with.

# %%
diabetespd.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#           7         8         9
# 0 -0.002592  0.019908 -0.017646
# 1 -0.039493 -0.068330 -0.092204
# 2 -0.002592  0.002864 -0.025930
# 3  0.034309  0.022692 -0.009362
# 4 -0.002592 -0.031991 -0.046641

# %%
diabetespd.describe()
# Out:
#                   0             1             2             3             4  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean  -3.634285e-16  1.308343e-16 -8.045349e-16  1.281655e-16 -8.835316e-17
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.072256e-01 -4.464164e-02 -9.027530e-02 -1.123996e-01 -1.267807e-01
# 25%   -3.729927e-02 -4.464164e-02 -3.422907e-02 -3.665645e-02 -3.424784e-02
# 50%    5.383060e-03 -4.464164e-02 -7.283766e-03 -5.670611e-03 -4.320866e-03
# 75%    3.807591e-02  5.068012e-02  3.124802e-02  3.564384e-02  2.835801e-02
# max    1.107267e-01  5.068012e-02  1.705552e-01  1.320442e-01  1.539137e-01
#
#                   5             6             7             8             9
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean   1.327024e-16 -4.574646e-16  3.777301e-16 -3.830854e-16 -3.412882e-16
# ...

# %%
diabetes_X = diabetes.data[:, np.newaxis, 2]

# %%
diabetes_X
# Out:
# array([[ 0.06169621],
#        [-0.05147406],
#        [ 0.04445121],
#        [-0.01159501],
#        [-0.03638469],
#        [-0.04069594],
#        [-0.04716281],
#        [-0.00189471],
#        [ 0.06169621],
#        [ 0.03906215],
#        [-0.08380842],
#        [ 0.01750591],
#        [-0.02884001],
#        [-0.00189471],
#        [-0.02560657],
#        [-0.01806189],
#        [ 0.04229559],
#        [ 0.01211685],
#        [-0.0105172 ],
#        [-0.01806189],
#        [-0.05686312],
#        [-0.02237314],
#        [-0.00405033],
#        [ 0.06061839],
#        [ 0.03582872],
#        [-0.01267283],
#        [-0.07734155],
#        [ 0.05954058],
#        [-0.02129532],
#        [-0.00620595],
#        [ 0.04445121],
#        [-0.06548562],
#        [ 0.12528712],
#        [-0.05039625],
#        [-0.06332999],
#        [-0.03099563],
#        [ 0.02289497],
#        [ 0.01103904],
#        [ 0.07139652],
#        [ 0.01427248],
#        [-0.00836158],
# ...

# %%
diabetes.target[:-20]
# Out:
# array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#         69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#         68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#         87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
#        259.,  53., 190., 142.,  75., 142., 155., 225.,  59., 104., 182.,
#        128.,  52.,  37., 170., 170.,  61., 144.,  52., 128.,  71., 163.,
#        150.,  97., 160., 178.,  48., 270., 202., 111.,  85.,  42., 170.,
#        200., 252., 113., 143.,  51.,  52., 210.,  65., 141.,  55., 134.,
#         42., 111.,  98., 164.,  48.,  96.,  90., 162., 150., 279.,  92.,
#         83., 128., 102., 302., 198.,  95.,  53., 134., 144., 232.,  81.,
#        104.,  59., 246., 297., 258., 229., 275., 281., 179., 200., 200.,
#        173., 180.,  84., 121., 161.,  99., 109., 115., 268., 274., 158.,
#        107.,  83., 103., 272.,  85., 280., 336., 281., 118., 317., 235.,
# ...
